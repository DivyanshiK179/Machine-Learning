# %% [markdown]
# # What is python?

# %%
Writing down some important codes for python

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Python is a programming language which is high level, interpreted and is used for general purposes.

# %% [markdown]
# ## Keywords and Identifiers

# %% [markdown]
# Keywords are some reserved words in python and they carry some meaning.

# %% [markdown]
# Identifiers:
# Rules to write:
# 1. We cannot use keywords as identifiers.
# 2. Identifiers can start only with alphabet or "_".
# 3. Special characters are not allowed.

# %%
_hey=37 #This is an identifier

# %% [markdown]
# Python is case sensitive.
