# %% [markdown]
# # Descriptive Analysis

# %% [markdown]
# 1. Data set is small in nature.
# 2. Mean, Median & Mode(Measure of Central Tendency).

# %% [markdown]
# ## Measure of Central Tendency

# %%
import pandas as pd
df=pd.read_csv("D:/Machine Learning/Car_prices.csv")
print(df)
# Out:
#     year       make      model         trim       body transmission  \
# 0   2006     Toyota      Camry          XLE      Sedan    automatic
# 1   2014      Honda      Civic           LX      Sedan    automatic
# 2   2009       Ford      F-150          XLT     Pickup    automatic
# 3   2012  Chevrolet      Cruze           LT      Sedan    automatic
# 4   2015        BMW   3 Series         328i      Sedan    automatic
# 5   2003     Toyota    Corolla           CE      Sedan       manual
# 6   2011      Honda       CR-V           EX        SUV    automatic
# 7   2013       Ford    Mustang      Premium      Coupe       manual
# 8   2010  Chevrolet  Silverado           LT     Pickup    automatic
# 9   2014        BMW         X5    xDrive35i        SUV    automatic
# 10  2008     Toyota      Prius         Base  Hatchback    automatic
# 11  2012      Honda     Accord         EX-L      Sedan    automatic
# 12  2005       Ford      Focus           SE      Sedan       manual
# ...

# %%
pd.DataFrame(df.dtypes, columns=['Data Type'])
# Out:
#              Data Type
# year             int64
# make            object
# model           object
# trim            object
# body            object
# transmission    object
# vin             object
# state           object
# condition      float64
# odometer         int64
# color           object
# interior        object
# seller          object
# mmr              int64
# sellingprice     int64
# saledate        object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          50 non-null     int64
#  1   make          50 non-null     object
#  2   model         50 non-null     object
#  3   trim          50 non-null     object
#  4   body          50 non-null     object
#  5   transmission  50 non-null     object
#  6   vin           50 non-null     object
#  7   state         50 non-null     object
#  8   condition     50 non-null     float64
#  9   odometer      50 non-null     int64
#  10  color         50 non-null     object
#  11  interior      50 non-null     object
#  12  seller        50 non-null     object
#  13  mmr           50 non-null     int64
#  14  sellingprice  50 non-null     int64
#  15  saledate      50 non-null     object
# dtypes: float64(1), int64(4), object(11)
# memory usage: 6.4+ KB

# %%
df.describe()
# Out:
#               year  condition       odometer           mmr  sellingprice
# count    50.000000  50.000000      50.000000     50.000000     50.000000
# mean   2011.120000   3.682000   75210.000000  12672.000000  12700.000000
# std       2.904184   0.713911   45368.568865   7893.656456   8084.553173
# min    2003.000000   1.900000   12000.000000   1200.000000   1000.000000
# 25%    2010.000000   3.200000   38250.000000   7525.000000   7725.000000
# 50%    2012.000000   3.750000   66000.000000  11250.000000  11200.000000
# 75%    2013.000000   4.275000  109250.000000  16225.000000  15950.000000
# max    2015.000000   4.800000  185000.000000  39000.000000  39500.000000

# %%
df.describe(include="object")
# Out:
#           make     model trim   body transmission                vin state  \
# count       50        50   50     50           50                 50    50
# unique       5        19   26      5            2                 47     9
# top     Toyota  3 Series   LT  Sedan    automatic  1A2B3C4D5E6F7G8H9    ca
# freq        10         5    6     24           43                  2     9
#
#         color interior            seller  \
# count      50       50                50
# unique      8        6                 4
# top     black    black  Auto Auction Inc
# freq       11       26                22
#
#                                        saledate
# count                                        50
# unique                                       50
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                          1

# %% [markdown]
# ### Measure of Dispersion

# %%
range1=df["sellingprice"].max()-df["sellingprice"].min()
print(range1)
# Out:
# 38500
